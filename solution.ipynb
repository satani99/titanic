# %%
import pandas as pd

# %%
data = pd.read_csv('train.csv')

# %%
data.shape
# Out:
# (891, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
X = data.drop("Survived", axis=1)
y = data["Survived"].copy()

# %%
X.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
median = X["Age"].median()

# %%
X["Age"].fillna(median, inplace=True)

# %%
X.drop("Cabin", axis=1)
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
X.drop("Embarked", axis=1)
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
X.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
X.drop("Name", axis=1)
# Out:
#      PassengerId  Pclass     Sex   Age  SibSp  Parch            Ticket  \
# 0              1       3    male  22.0      1      0         A/5 21171
# 1              2       1  female  38.0      1      0          PC 17599
# 2              3       3  female  26.0      0      0  STON/O2. 3101282
# 3              4       1  female  35.0      1      0            113803
# 4              5       3    male  35.0      0      0            373450
# ..           ...     ...     ...   ...    ...    ...               ...
# 886          887       2    male  27.0      0      0            211536
# 887          888       1  female  19.0      0      0            112053
# 888          889       3  female  28.0      1      2        W./C. 6607
# 889          890       1    male  26.0      0      0            111369
# 890          891       3    male  32.0      0      0            370376
#
#         Fare Cabin Embarked
# 0     7.2500   NaN        S
# 1    71.2833   C85        C
# ...

# %%
X = X[["Pclass", "Sex", "Age"]]
X.head()
# Out:
#    Pclass     Sex   Age
# 0       3    male  22.0
# 1       1  female  38.0
# 2       3  female  26.0
# 3       1  female  35.0
# 4       3    male  35.0

# %%
X_cat = X[["Sex"]]

# %%
X_cat.head()
# Out:
#       Sex
# 0    male
# 1  female
# 2  female
# 3  female
# 4    male

# %%
from sklearn.preprocessing import OrdinalEncoder

ordinal_encoder = OrdinalEncoder()
X_cat_encoded = ordinal_encoder.fit_transform(X_cat)
type(X_cat_encoded)
# Out:
# numpy.ndarray

# %%
ordinal_encoder.categories_
# Out:
# [array(['female', 'male'], dtype=object)]

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# %%
X['gender_factor'] = pd.factorize(X.Sex)[0]

# %%
X = X.drop('Sex', axis=1)

# %%
X_train, X_test, y_train, y_test = X[:714], X[714:], y[:714], y[714:]

# %%
y_train_1 = (y_train == 1)
y_test_1 = (y_test == 1)

# %%
from sklearn.linear_model import SGDClassifier

sgd_clf = SGDClassifier(random_state = 42)
sgd_clf.fit(X_train, y_train_1)
# Out:
# SGDClassifier(random_state=42)

# %%
from sklearn.model_selection import cross_val_predict

# %%
from sklearn.ensemble import RandomForestClassifier

forest_clf = RandomForestClassifier(random_state=42)
y_probas_forest = cross_val_predict(forest_clf, X_train, y_train_1, cv=3, method="predict_proba")

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(sgd_clf, X_train, y_train_1, cv=3, scoring="accuracy")
# Out:
# array([0.66806723, 0.63865546, 0.75630252])

# %%
from sklearn.metrics import roc_curve

# %%
from sklearn.metrics import roc_auc_score

# %%
y_scores_forest = y_probas_forest[:, 1]
fpr_forest, tpr_forest, thresholds_forest = roc_curve(y_train_1, y_scores_forest)

# %%
roc_auc_score(y_train_1, y_scores_forest)
# Out:
# 0.8228690314341038

# %%
forest_clf.fit(X_train, y_train_1)
# Out:
# RandomForestClassifier(random_state=42)

# %%
pred = forest_clf.predict(X_test)

# %%
import numpy as np

# %%
prediction = np.where(pred == True, 1, 0)

# %%
test_case = pd.read_csv('test.csv')

# %%
test_case_1 = pd.read_csv('test.csv')
test_case_1.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test_case = test_case[["Pclass", "Sex", "Age"]]
test_case['gender_factor'] = pd.factorize(test_case.Sex)[0]
test_case = test_case.drop('Sex', axis=1)

# %%
test_case.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Pclass         418 non-null    int64
#  1   Age            332 non-null    float64
#  2   gender_factor  418 non-null    int64
# dtypes: float64(1), int64(2)
# memory usage: 9.9 KB

# %%
median = test_case["Age"].median()
test_case["Age"].fillna(median, inplace=True)

# %%
sub = forest_clf.predict(test_case)

# %%
submission = np.where(sub == True, 1, 0)

# %%
solution = pd.DataFrame({'PassengerId': test_case_1.PassengerId, 'Survived': submission})

# %%
solution.to_csv('solution.csv', index=False)

# %%
a = pd.read_csv('solution.csv')

# %%
a.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         1
# 3          895         0
# 4          896         1

# %%
from sklearn.neighbors import KNeighborsClassifier
